# %%
import os
import time
import torch
import numpy as np
import torch.nn as nn
import torch.nn.functional as F

import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader

from Models import ResNet20, ResNet50

# %% [markdown]
# ## Test network

# %%
input_test = torch.randn([5,3,32,32])
resnet20 = ResNet20()
out = resnet20(input_test)
print(out.size())

resnet50 = ResNet50()
out = resnet50(input_test)
print(out.size())
# Out:
# torch.Size([5, 10])
# torch.Size([5, 10])

# %% [markdown]
# ## Data Preprocess

# %%
DATA_ROOT = "./data"
CIFAR10_shape = (3, 32, 32)
pad_size = 2
BATCH_SIZE = 128


# Preprocessing
transform_train = transforms.Compose([torchvision.transforms.RandomHorizontalFlip(p=0.5),
                                      torchvision.transforms.RandomCrop((32,32), padding=4),
                                      transforms.ToTensor(), 
                                      transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))])

transform_val = transforms.Compose([transforms.ToTensor(), 
                                    transforms.Normalize((0.4914, 0.4822, 0.4465),
                                    (0.2023, 0.1994, 0.2010))])

transform_test = transforms.Compose([transforms.ToTensor(), 
                                    transforms.Normalize((0.4914, 0.4822, 0.4465),
                                    (0.2023, 0.1994, 0.2010))])

train_CIFAR10 = torchvision.datasets.CIFAR10(root='./', train=True, download=True, transform = transform_train)

test_CIFAR10 = torchvision.datasets.CIFAR10(root='./', train=False, download=True, transform=transform_test)

num_train = int(1.0 * len(train_CIFAR10) * 95 / 100)
num_val = len(train_CIFAR10) - num_train
train_CIFAR10, val_CIFAR10 = torch.utils.data.random_split(train_CIFAR10, [num_train, num_val])

train_loader = DataLoader(
    train_CIFAR10, 
    batch_size=BATCH_SIZE,
    shuffle=True,
    num_workers=4
)

val_loader = DataLoader(
    val_CIFAR10, 
    batch_size=BATCH_SIZE,
    shuffle=True,
    num_workers=4
)

test_loader = DataLoader(
    test_CIFAR10, 
    batch_size=BATCH_SIZE,
    shuffle=True,
    num_workers=4
)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("The model is deployed to", device)

resnet20 = ResNet20().to(device)
resnet50 = ResNet50().to(device)
# Out:
# The model is deployed to cuda

# %% [markdown]
# ## Define Training and Testing Function

# %%
def train_model(model, mode):
    # some hyperparameters
    # total number of training epochs
    EPOCHS = 150

    # learning rate decay policy
    DECAY_EPOCHS = [75,110]
    DECAY = 0.1

    # the folder where the trained model is saved
    CHECKPOINT_PATH = "./saved_model"

    # start the training/validation process
    # the process should take about 5 minutes on a GTX 1070-Ti
    # if the code is written efficiently.
    best_val_acc = 0
    current_learning_rate = INITIAL_LR

    print("==> Training starts!")
    print("="*50)
    for i in range(0, EPOCHS):
        # handle the learning rate scheduler.
        if i in DECAY_EPOCHS and i != 0:
            current_learning_rate = current_learning_rate * DECAY
            for param_group in optimizer.param_groups:
                param_group['lr'] = current_learning_rate
            print("Current learning rate has decayed to %f" %current_learning_rate)

        model.train()

        print("Epoch %d:" %i)
        # this help you compute the training accuracy
        total_examples = 0
        correct_examples = 0

        train_loss = 0 # track training loss if you want

        # Train the model for 1 epoch.
        for batch_idx, (inputs, targets) in enumerate(train_loader):
            inputs, targets = inputs.to(device), targets.to(device)

            # compute the output and loss
            y_preds = model(inputs)        
            loss = criterion(y_preds,targets)
            train_loss += loss

            # zero the gradient
            optimizer.zero_grad()

            # backpropagation
            loss.backward()

            # apply gradient and update the weights
            optimizer.step()

            # count the number of correctly predicted samples in the current batch
            y_preds_class = torch.argmax(y_preds, dim=1)
            correct_examples += (targets == y_preds_class).sum().item()
            total_examples += targets.size(0)

        avg_loss = train_loss / len(train_loader)
        avg_acc = correct_examples / total_examples
        print("Training loss: %.4f, Training accuracy: %.4f" %(avg_loss, avg_acc))

        # switch to eval mode
        model.eval()

        total_examples = 0
        correct_examples = 0

        val_loss = 0 # again, track the validation loss if you want

        # disable gradient during validation, which can save GPU memory
        with torch.no_grad():
            for batch_idx, (inputs, targets) in enumerate(val_loader):
                inputs, targets = inputs.to(device), targets.to(device)

                # compute the output and loss
                y_preds = model(inputs)        
                loss = criterion(y_preds,targets)
                val_loss += loss

                # count the number of correctly predicted samples in the current batch
                y_preds_class = torch.argmax(y_preds, dim=1)
                correct_examples += (targets == y_preds_class).sum().item()
                total_examples += targets.size(0)

        avg_loss = val_loss / len(val_loader)
        avg_acc = correct_examples / total_examples
        print("Validation loss: %.4f, Validation accuracy: %.4f" % (avg_loss, avg_acc))

        # save the model checkpoint
        if avg_acc > best_val_acc:
            best_val_acc = avg_acc
            if not os.path.exists(CHECKPOINT_PATH):
                os.makedirs(CHECKPOINT_PATH)
            print("Saving ...")
            state = {'state_dict': model.state_dict(),
                     'epoch': i,
                     'lr': current_learning_rate}
            if mode == 'resnet20':
                torch.save(state, os.path.join(CHECKPOINT_PATH, 'resnet20.pth'))
            elif mode == 'resnet50':
                torch.save(state, os.path.join(CHECKPOINT_PATH, 'resnet50.pth'))
            else:
                raise Exception('Mode not exist')

        print('')

    print("="*50)
    print(f"==> Optimization finished! Best validation accuracy: {best_val_acc:.4f}")

# %%
def test_model(model):
    model.to(device)
    model.eval()

    total_examples = 0
    correct_examples = 0
    softmax = torch.nn.Softmax(dim=1)

    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(test_loader):
            inputs, targets = inputs.to(device), targets.to(device)
            pred = model(inputs)
            total_examples += inputs.shape[0]

            out = softmax(pred)
            out = torch.max(out, 1)

            correct_examples += torch.sum(targets==out[1]).cpu().data.numpy().tolist()

    avg_acc = correct_examples / total_examples
    print("Total examples is {}, correct examples is {}; Test accuracy: {}".format(total_examples, correct_examples, avg_acc))

# %% [markdown]
# ## ResNet20 Model

# %%
INITIAL_LR = 0.01

# momentum for optimizer
MOMENTUM = 0.9

# L2 regularization strength
REG = 1e-4

# Define loss
criterion = nn.CrossEntropyLoss()

# Add optimizer
optimizer = torch.optim.SGD(resnet20.parameters(), lr=INITIAL_LR, momentum=MOMENTUM, weight_decay=REG)

# %%
train_model(resnet20, "resnet20")
# Out:
# ==> Training starts!
# ==================================================
# Epoch 0:
# Training loss: 1.5555, Training accuracy: 0.4207
# Validation loss: 1.6231, Validation accuracy: 0.4148
# Saving ...
#
# Epoch 1:
# Training loss: 1.1050, Training accuracy: 0.6001
# Validation loss: 1.2231, Validation accuracy: 0.5660
# Saving ...
#
# Epoch 2:
# Training loss: 0.9277, Training accuracy: 0.6701
# Validation loss: 0.9561, Validation accuracy: 0.6648
# Saving ...
#
# Epoch 3:
# Training loss: 0.8099, Training accuracy: 0.7148
# Validation loss: 0.8946, Validation accuracy: 0.6856
# Saving ...
#
# Epoch 4:
# Training loss: 0.7235, Training accuracy: 0.7475
# Validation loss: 0.7908, Validation accuracy: 0.7284
# Saving ...
#
# Epoch 5:
# Training loss: 0.6652, Training accuracy: 0.7691
# Validation loss: 0.7477, Validation accuracy: 0.7472
# Saving ...
#
# Epoch 6:
# Training loss: 0.6127, Training accuracy: 0.7889
# Validation loss: 0.7014, Validation accuracy: 0.7548
# Saving ...
#
# Epoch 7:
# Training loss: 0.5726, Training accuracy: 0.8007
# Validation loss: 0.6193, Validation accuracy: 0.7784
# Saving ...
#
# Epoch 8:
# Training loss: 0.5442, Training accuracy: 0.8127
# Validation loss: 0.6263, Validation accuracy: 0.7940
# Saving ...
#
# Epoch 9:
# Training loss: 0.5158, Training accuracy: 0.8223
# Validation loss: 0.6229, Validation accuracy: 0.7876
#
# Epoch 10:
# Training loss: 0.4946, Training accuracy: 0.8291
# Validation loss: 0.6357, Validation accuracy: 0.7812
#
# Epoch 11:
# Training loss: 0.4680, Training accuracy: 0.8388
# Validation loss: 0.5520, Validation accuracy: 0.8028
# Saving ...
#
# Epoch 12:
# Training loss: 0.4527, Training accuracy: 0.8437
# Validation loss: 0.5597, Validation accuracy: 0.8064
# Saving ...
#
# Epoch 13:
# Training loss: 0.4352, Training accuracy: 0.8483
# Validation loss: 0.5734, Validation accuracy: 0.8136
# Saving ...
#
# Epoch 14:
# Training loss: 0.4163, Training accuracy: 0.8552
# Validation loss: 0.5738, Validation accuracy: 0.8180
# Saving ...
#
# Epoch 15:
# Training loss: 0.4055, Training accuracy: 0.8602
# Validation loss: 0.5558, Validation accuracy: 0.8132
#
# Epoch 16:
# Training loss: 0.3887, Training accuracy: 0.8650
# Validation loss: 0.5860, Validation accuracy: 0.8036
#
# Epoch 17:
# Training loss: 0.3799, Training accuracy: 0.8694
# Validation loss: 0.4654, Validation accuracy: 0.8408
# Saving ...
#
# Epoch 18:
# Training loss: 0.3751, Training accuracy: 0.8704
# Validation loss: 0.4857, Validation accuracy: 0.8368
#
# Epoch 19:
# Training loss: 0.3577, Training accuracy: 0.8777
# Validation loss: 0.5193, Validation accuracy: 0.8296
#
# Epoch 20:
# Training loss: 0.3535, Training accuracy: 0.8772
# Validation loss: 0.5143, Validation accuracy: 0.8320
#
# Epoch 21:
# Training loss: 0.3441, Training accuracy: 0.8806
# Validation loss: 0.4540, Validation accuracy: 0.8452
# Saving ...
#
# Epoch 22:
# Training loss: 0.3353, Training accuracy: 0.8839
# Validation loss: 0.5358, Validation accuracy: 0.8272
#
# Epoch 23:
# Training loss: 0.3298, Training accuracy: 0.8861
# Validation loss: 0.4926, Validation accuracy: 0.8348
#
# Epoch 24:
# Training loss: 0.3123, Training accuracy: 0.8929
# Validation loss: 0.4057, Validation accuracy: 0.8640
# Saving ...
#
# Epoch 25:
# Training loss: 0.3064, Training accuracy: 0.8934
# Validation loss: 0.4576, Validation accuracy: 0.8496
#
# Epoch 26:
# Training loss: 0.3007, Training accuracy: 0.8965
# Validation loss: 0.4396, Validation accuracy: 0.8512
#
# Epoch 27:
# Training loss: 0.2940, Training accuracy: 0.8989
# Validation loss: 0.4512, Validation accuracy: 0.8492
#
# Epoch 28:
# Training loss: 0.2878, Training accuracy: 0.8999
# Validation loss: 0.4203, Validation accuracy: 0.8604
#
# Epoch 29:
# Training loss: 0.2813, Training accuracy: 0.9027
# Validation loss: 0.4440, Validation accuracy: 0.8500
#
# Epoch 30:
# Training loss: 0.2829, Training accuracy: 0.9020
# Validation loss: 0.4014, Validation accuracy: 0.8668
# Saving ...
#
# Epoch 31:
# Training loss: 0.2749, Training accuracy: 0.9048
# Validation loss: 0.4249, Validation accuracy: 0.8548
#
# Epoch 32:
# Training loss: 0.2601, Training accuracy: 0.9086
# Validation loss: 0.4956, Validation accuracy: 0.8356
#
# Epoch 33:
# Training loss: 0.2541, Training accuracy: 0.9118
# Validation loss: 0.4985, Validation accuracy: 0.8312
#
# Epoch 34:
# Training loss: 0.2573, Training accuracy: 0.9105
# Validation loss: 0.5380, Validation accuracy: 0.8372
#
# Epoch 35:
# Training loss: 0.2627, Training accuracy: 0.9080
# Validation loss: 0.5258, Validation accuracy: 0.8328
#
# Epoch 36:
# Training loss: 0.2492, Training accuracy: 0.9137
# Validation loss: 0.4812, Validation accuracy: 0.8428
#
# Epoch 37:
# Training loss: 0.2506, Training accuracy: 0.9123
# Validation loss: 0.4266, Validation accuracy: 0.8644
#
# Epoch 38:
# Training loss: 0.2454, Training accuracy: 0.9146
# Validation loss: 0.4393, Validation accuracy: 0.8536
#
# Epoch 39:
# Training loss: 0.2296, Training accuracy: 0.9205
# Validation loss: 0.4191, Validation accuracy: 0.8600
#
# Epoch 40:
# Training loss: 0.2246, Training accuracy: 0.9199
# Validation loss: 0.4051, Validation accuracy: 0.8672
# Saving ...
#
# Epoch 41:
# Training loss: 0.2217, Training accuracy: 0.9220
# Validation loss: 0.4228, Validation accuracy: 0.8668
#
# Epoch 42:
# Training loss: 0.2171, Training accuracy: 0.9241
# Validation loss: 0.4788, Validation accuracy: 0.8488
#
# Epoch 43:
# Training loss: 0.2182, Training accuracy: 0.9240
# Validation loss: 0.4866, Validation accuracy: 0.8412
#
# Epoch 44:
# Training loss: 0.2131, Training accuracy: 0.9252
# Validation loss: 0.4132, Validation accuracy: 0.8672
#
# Epoch 45:
# Training loss: 0.2207, Training accuracy: 0.9229
# Validation loss: 0.4091, Validation accuracy: 0.8676
# Saving ...
#
# Epoch 46:
# Training loss: 0.2089, Training accuracy: 0.9270
# Validation loss: 0.4502, Validation accuracy: 0.8636
#
# Epoch 47:
# Training loss: 0.2084, Training accuracy: 0.9261
# Validation loss: 0.4137, Validation accuracy: 0.8664
#
# Epoch 48:
# Training loss: 0.2014, Training accuracy: 0.9288
# Validation loss: 0.4231, Validation accuracy: 0.8712
# Saving ...
#
# Epoch 49:
# Training loss: 0.1945, Training accuracy: 0.9313
# Validation loss: 0.4157, Validation accuracy: 0.8684
#
# Epoch 50:
#
# Epoch 96:
# Training loss: 0.0587, Training accuracy: 0.9805
# Validation loss: 0.3639, Validation accuracy: 0.8972
#
# Epoch 97:
# Training loss: 0.0545, Training accuracy: 0.9825
# Validation loss: 0.3642, Validation accuracy: 0.8960
#
# Epoch 98:
# Training loss: 0.0554, Training accuracy: 0.9822
# Validation loss: 0.3577, Validation accuracy: 0.9032
#
# Epoch 99:
# Training loss: 0.0541, Training accuracy: 0.9831
# Validation loss: 0.3317, Validation accuracy: 0.8968
#
# Epoch 100:
# Training loss: 0.0512, Training accuracy: 0.9843
# Validation loss: 0.3774, Validation accuracy: 0.8968
#
# Epoch 101:
# Training loss: 0.0554, Training accuracy: 0.9821
# Validation loss: 0.3564, Validation accuracy: 0.9000
#
# Epoch 102:
# Training loss: 0.0526, Training accuracy: 0.9829
# Validation loss: 0.3753, Validation accuracy: 0.8960
#
# Epoch 103:
# Training loss: 0.0526, Training accuracy: 0.9840
# Validation loss: 0.3674, Validation accuracy: 0.8928
#
# Epoch 104:
# Training loss: 0.0539, Training accuracy: 0.9837
# Validation loss: 0.3624, Validation accuracy: 0.8984
#
# Epoch 105:
# Training loss: 0.0515, Training accuracy: 0.9833
# Validation loss: 0.3856, Validation accuracy: 0.8964
#
# Epoch 106:
# Training loss: 0.0505, Training accuracy: 0.9839
# Validation loss: 0.3477, Validation accuracy: 0.8972
#
# Epoch 107:
# Training loss: 0.0505, Training accuracy: 0.9836
# Validation loss: 0.3695, Validation accuracy: 0.8912
#
# Epoch 108:
# Training loss: 0.0510, Training accuracy: 0.9838
# Validation loss: 0.3606, Validation accuracy: 0.9012
#
# Epoch 109:
# Training loss: 0.0510, Training accuracy: 0.9846
# Validation loss: 0.3621, Validation accuracy: 0.9008
#
# Current learning rate has decayed to 0.000100
# Epoch 110:
# Training loss: 0.0471, Training accuracy: 0.9858
# Validation loss: 0.3732, Validation accuracy: 0.8968
#
# Epoch 111:
# Training loss: 0.0474, Training accuracy: 0.9855
# Validation loss: 0.3909, Validation accuracy: 0.8932
#
# Epoch 112:
# Training loss: 0.0486, Training accuracy: 0.9854
# Validation loss: 0.3886, Validation accuracy: 0.8920
#
# Epoch 113:
# Training loss: 0.0457, Training accuracy: 0.9856
# Validation loss: 0.3334, Validation accuracy: 0.9000
#
# Epoch 114:
# Training loss: 0.0463, Training accuracy: 0.9859
# Validation loss: 0.3531, Validation accuracy: 0.8992
#
# Epoch 115:
# Training loss: 0.0459, Training accuracy: 0.9858
# Validation loss: 0.3762, Validation accuracy: 0.8960
#
# Epoch 116:
# Training loss: 0.0468, Training accuracy: 0.9857
# Validation loss: 0.3617, Validation accuracy: 0.9028
#
# Epoch 117:
# Training loss: 0.0454, Training accuracy: 0.9859
# Validation loss: 0.3705, Validation accuracy: 0.8964
#
# Epoch 118:
# Training loss: 0.0457, Training accuracy: 0.9857
# Validation loss: 0.3539, Validation accuracy: 0.8968
#
# Epoch 119:
#
# Epoch 146:
# Training loss: 0.0427, Training accuracy: 0.9876
# Validation loss: 0.3560, Validation accuracy: 0.9064
#
# Epoch 147:
# Training loss: 0.0443, Training accuracy: 0.9869
# Validation loss: 0.3871, Validation accuracy: 0.9020
#
# Epoch 148:
# Training loss: 0.0441, Training accuracy: 0.9870
# Validation loss: 0.3786, Validation accuracy: 0.8984
#
# Epoch 149:
# Training loss: 0.0430, Training accuracy: 0.9872
# Validation loss: 0.3643, Validation accuracy: 0.8972
#
# ==================================================
# ==> Optimization finished! Best validation accuracy: 0.9080

# %%
resnet20 = ResNet20()
checkpoint = torch.load("./saved_model/resnet20.pth")
resnet20.load_state_dict(checkpoint['state_dict'])

test_model(resnet20)
# Out:
# Total examples is 10000, correct examples is 8967; Test accuracy: 0.8967

# %% [markdown]
# ## ResNet50

# %%
INITIAL_LR = 0.01

# momentum for optimizer
MOMENTUM = 0.9

# L2 regularization strength
REG = 1e-4

# Define loss
criterion = nn.CrossEntropyLoss()

# Add optimizer
optimizer = torch.optim.SGD(resnet50.parameters(), lr=INITIAL_LR, momentum=MOMENTUM, weight_decay=REG)

# %%
train_model(resnet50, "resnet50")
# Out:
# ==> Training starts!
# ==================================================
# Epoch 0:
# Training loss: 1.4989, Training accuracy: 0.4452
# Validation loss: 1.5594, Validation accuracy: 0.4268
# Saving ...
#
# Epoch 1:
# Training loss: 1.1586, Training accuracy: 0.5820
# Validation loss: 1.1808, Validation accuracy: 0.5792
# Saving ...
#
# Epoch 2:
# Training loss: 0.9546, Training accuracy: 0.6619
# Validation loss: 1.0306, Validation accuracy: 0.6236
# Saving ...
#
# Epoch 3:
# Training loss: 0.8147, Training accuracy: 0.7143
# Validation loss: 0.7943, Validation accuracy: 0.7284
# Saving ...
#
# Epoch 4:
# Training loss: 0.7184, Training accuracy: 0.7483
# Validation loss: 0.7780, Validation accuracy: 0.7312
# Saving ...
#
# Epoch 5:
# Training loss: 0.6531, Training accuracy: 0.7722
# Validation loss: 0.7320, Validation accuracy: 0.7444
# Saving ...
#
# Epoch 6:
# Training loss: 0.6025, Training accuracy: 0.7924
# Validation loss: 0.6469, Validation accuracy: 0.7808
# Saving ...
#
# Epoch 7:
# Training loss: 0.5567, Training accuracy: 0.8071
# Validation loss: 0.6832, Validation accuracy: 0.7672
#
# Epoch 8:
# Training loss: 0.5216, Training accuracy: 0.8203
# Validation loss: 0.6107, Validation accuracy: 0.7932
# Saving ...
#
# Epoch 9:
# Training loss: 0.4985, Training accuracy: 0.8286
# Validation loss: 0.6586, Validation accuracy: 0.7736
#
# Epoch 10:
# Training loss: 0.4705, Training accuracy: 0.8379
# Validation loss: 0.7049, Validation accuracy: 0.7592
#
# Epoch 11:
# Training loss: 0.4432, Training accuracy: 0.8449
# Validation loss: 0.5236, Validation accuracy: 0.8192
# Saving ...
#
# Epoch 12:
# Training loss: 0.4207, Training accuracy: 0.8542
# Validation loss: 0.5948, Validation accuracy: 0.7984
#
# Epoch 13:
# Training loss: 0.4049, Training accuracy: 0.8581
# Validation loss: 0.5559, Validation accuracy: 0.8168
#
# Epoch 14:
# Training loss: 0.3932, Training accuracy: 0.8631
# Validation loss: 0.5981, Validation accuracy: 0.7988
#
# Epoch 15:
# Training loss: 0.3763, Training accuracy: 0.8709
# Validation loss: 0.5073, Validation accuracy: 0.8268
# Saving ...
#
# Epoch 16:
# Training loss: 0.3571, Training accuracy: 0.8767
# Validation loss: 0.4795, Validation accuracy: 0.8308
# Saving ...
#
# Epoch 17:
# Training loss: 0.3488, Training accuracy: 0.8786
# Validation loss: 0.4808, Validation accuracy: 0.8452
# Saving ...
#
# Epoch 18:
# Training loss: 0.3340, Training accuracy: 0.8839
# Validation loss: 0.5095, Validation accuracy: 0.8284
#
# Epoch 19:
# Training loss: 0.3195, Training accuracy: 0.8893
# Validation loss: 0.5048, Validation accuracy: 0.8264
#
# Epoch 20:
# Training loss: 0.3141, Training accuracy: 0.8911
# Validation loss: 0.4868, Validation accuracy: 0.8408
#
# Epoch 21:
# Training loss: 0.3056, Training accuracy: 0.8932
# Validation loss: 0.4958, Validation accuracy: 0.8316
#
# Epoch 22:
# Training loss: 0.2917, Training accuracy: 0.8990
# Validation loss: 0.4693, Validation accuracy: 0.8416
#
# Epoch 23:
# Training loss: 0.2828, Training accuracy: 0.9017
# Validation loss: 0.5082, Validation accuracy: 0.8412
#
# Epoch 24:
# Training loss: 0.2789, Training accuracy: 0.9032
# Validation loss: 0.4860, Validation accuracy: 0.8424
#
# Epoch 25:
# Training loss: 0.2709, Training accuracy: 0.9062
# Validation loss: 0.4857, Validation accuracy: 0.8440
#
# Epoch 26:
# Training loss: 0.2637, Training accuracy: 0.9080
# Validation loss: 0.4504, Validation accuracy: 0.8536
# Saving ...
#
# Epoch 27:
# Training loss: 0.2478, Training accuracy: 0.9131
# Validation loss: 0.4129, Validation accuracy: 0.8640
# Saving ...
#
# Epoch 28:
# Training loss: 0.2503, Training accuracy: 0.9107
# Validation loss: 0.5108, Validation accuracy: 0.8388
#
# Epoch 29:
# Training loss: 0.2349, Training accuracy: 0.9170
# Validation loss: 0.4342, Validation accuracy: 0.8612
#
# Epoch 30:
# Training loss: 0.2310, Training accuracy: 0.9189
# Validation loss: 0.4154, Validation accuracy: 0.8612
#
# Epoch 31:
# Training loss: 0.2330, Training accuracy: 0.9195
# Validation loss: 0.4073, Validation accuracy: 0.8628
#
# Epoch 32:
# Training loss: 0.2281, Training accuracy: 0.9201
# Validation loss: 0.4151, Validation accuracy: 0.8644
# Saving ...
#
# Epoch 33:
# Training loss: 0.2104, Training accuracy: 0.9265
# Validation loss: 0.4480, Validation accuracy: 0.8560
#
# Epoch 34:
# Training loss: 0.2092, Training accuracy: 0.9267
# Validation loss: 0.4527, Validation accuracy: 0.8580
#
# Epoch 35:
# Training loss: 0.2042, Training accuracy: 0.9264
# Validation loss: 0.5151, Validation accuracy: 0.8448
#
# Epoch 36:
# Training loss: 0.1218, Training accuracy: 0.9557
# Validation loss: 0.3993, Validation accuracy: 0.8836
#
# Epoch 60:
# Training loss: 0.1125, Training accuracy: 0.9612
# Validation loss: 0.4001, Validation accuracy: 0.8896
#
# Epoch 61:
# Training loss: 0.1288, Training accuracy: 0.9547
# Validation loss: 0.4390, Validation accuracy: 0.8828
#
# Epoch 62:
# Training loss: 0.1121, Training accuracy: 0.9604
# Validation loss: 0.3767, Validation accuracy: 0.8848
#
# Epoch 63:
# Training loss: 0.1058, Training accuracy: 0.9618
# Validation loss: 0.4152, Validation accuracy: 0.8864
#
# Epoch 64:
# Training loss: 0.1173, Training accuracy: 0.9582
# Validation loss: 0.4639, Validation accuracy: 0.8788
#
# Epoch 65:
# Training loss: 0.1033, Training accuracy: 0.9635
# Validation loss: 0.4409, Validation accuracy: 0.8744
#
# Epoch 66:
# Training loss: 0.1006, Training accuracy: 0.9650
# Validation loss: 0.4172, Validation accuracy: 0.8792
#
# Epoch 67:
# Training loss: 0.0983, Training accuracy: 0.9660
# Validation loss: 0.5156, Validation accuracy: 0.8564
#
# Epoch 68:
# Training loss: 0.1242, Training accuracy: 0.9569
# Validation loss: 0.4383, Validation accuracy: 0.8808
#
# Epoch 69:
# Training loss: 0.0954, Training accuracy: 0.9650
# Validation loss: 0.4586, Validation accuracy: 0.8756
#
# Epoch 70:
# Training loss: 0.0925, Training accuracy: 0.9667
# Validation loss: 0.4243, Validation accuracy: 0.8864
#
# Epoch 71:
# Training loss: 0.0955, Training accuracy: 0.9661
# Validation loss: 0.4602, Validation accuracy: 0.8724
#
# Epoch 72:
# Training loss: 0.0957, Training accuracy: 0.9659
# Validation loss: 0.4058, Validation accuracy: 0.8852
#
# Epoch 73:
# Training loss: 0.1036, Training accuracy: 0.9635
# Validation loss: 0.4447, Validation accuracy: 0.8764
#
# Epoch 74:
# Training loss: 0.0884, Training accuracy: 0.9683
# Validation loss: 0.4560, Validation accuracy: 0.8844
#
# Current learning rate has decayed to 0.001000
# Epoch 75:
# Training loss: 0.0502, Training accuracy: 0.9831
# Validation loss: 0.3649, Validation accuracy: 0.8964
# Saving ...
#
# Epoch 76:
# Training loss: 0.0397, Training accuracy: 0.9877
# Validation loss: 0.3394, Validation accuracy: 0.9084
# Saving ...
#
# Epoch 77:
# Training loss: 0.0351, Training accuracy: 0.9897
# Validation loss: 0.3540, Validation accuracy: 0.9052
#
# Epoch 78:
# Training loss: 0.0315, Training accuracy: 0.9906
# Validation loss: 0.3746, Validation accuracy: 0.8996
#
# Epoch 79:
# Training loss: 0.0304, Training accuracy: 0.9910
# Validation loss: 0.3478, Validation accuracy: 0.9020
#
# Epoch 80:
# Training loss: 0.0281, Training accuracy: 0.9915
# Validation loss: 0.3435, Validation accuracy: 0.9072
#
# Epoch 81:
# Training loss: 0.0269, Training accuracy: 0.9918
# Validation loss: 0.3398, Validation accuracy: 0.9088
# Saving ...
#
# Epoch 82:
# Training loss: 0.0254, Training accuracy: 0.9925
# Validation loss: 0.3701, Validation accuracy: 0.9040
#
# Epoch 83:
# Training loss: 0.0244, Training accuracy: 0.9925
# Validation loss: 0.3880, Validation accuracy: 0.8972
#
# Epoch 84:
# Training loss: 0.0226, Training accuracy: 0.9940
# Validation loss: 0.3707, Validation accuracy: 0.9096
# Saving ...
#
# Epoch 85:
# Training loss: 0.0235, Training accuracy: 0.9929
# Validation loss: 0.3808, Validation accuracy: 0.9048
#
# Epoch 86:
# Training loss: 0.0220, Training accuracy: 0.9939
# Validation loss: 0.3842, Validation accuracy: 0.9008
#
# Epoch 87:
# Training loss: 0.0223, Training accuracy: 0.9939
# Validation loss: 0.3709, Validation accuracy: 0.9072
#
# Epoch 88:
# Training loss: 0.0246, Training accuracy: 0.9937
# Validation loss: 0.3782, Validation accuracy: 0.9024
#
# Epoch 89:
# Training loss: 0.0242, Training accuracy: 0.9926
# Validation loss: 0.3829, Validation accuracy: 0.9096
#
# Epoch 90:
# Training loss: 0.0203, Training accuracy: 0.9941
# Validation loss: 0.3834, Validation accuracy: 0.9076
#
# Epoch 91:
# Training loss: 0.0177, Training accuracy: 0.9953
# Validation loss: 0.3887, Validation accuracy: 0.9088
#
# Epoch 92:
# Training loss: 0.0191, Training accuracy: 0.9945
# Validation loss: 0.3975, Validation accuracy: 0.9044
#
# Epoch 93:
# Training loss: 0.0181, Training accuracy: 0.9948
# Validation loss: 0.3810, Validation accuracy: 0.9020
#
# Epoch 94:
# Training loss: 0.0184, Training accuracy: 0.9946
# Validation loss: 0.3715, Validation accuracy: 0.9032
#
# Epoch 95:
# Training loss: 0.0173, Training accuracy: 0.9953
# Validation loss: 0.3670, Validation accuracy: 0.9104
# Saving ...
#
# Epoch 96:
# Training loss: 0.0171, Training accuracy: 0.9953
# Validation loss: 0.4032, Validation accuracy: 0.9040
#
# Epoch 97:
# Training loss: 0.0171, Training accuracy: 0.9953
# Validation loss: 0.3819, Validation accuracy: 0.9144
# Saving ...
#
# Epoch 98:
# Training loss: 0.0159, Training accuracy: 0.9959
# Validation loss: 0.3930, Validation accuracy: 0.9120
#
# Epoch 99:
# Training loss: 0.0171, Training accuracy: 0.9962
# Validation loss: 0.3977, Validation accuracy: 0.9048
#
# Epoch 100:
# Training loss: 0.0168, Training accuracy: 0.9956
# Validation loss: 0.3933, Validation accuracy: 0.9076
#
# Epoch 101:
# Training loss: 0.0166, Training accuracy: 0.9959
# Validation loss: 0.3814, Validation accuracy: 0.9144
#
# Epoch 102:
# Training loss: 0.0166, Training accuracy: 0.9952
# Validation loss: 0.4096, Validation accuracy: 0.9052
#
# Epoch 103:
# Training loss: 0.0149, Training accuracy: 0.9961
# Validation loss: 0.4038, Validation accuracy: 0.9068
#
# Epoch 104:
# Training loss: 0.0148, Training accuracy: 0.9959
# Validation loss: 0.3785, Validation accuracy: 0.9092
#
# Epoch 105:
# Training loss: 0.0142, Training accuracy: 0.9965
# Validation loss: 0.4020, Validation accuracy: 0.9076
#
# Epoch 106:
# Training loss: 0.0157, Training accuracy: 0.9963
# Validation loss: 0.3898, Validation accuracy: 0.9100
#
# Epoch 107:
# Training loss: 0.0155, Training accuracy: 0.9958
# Validation loss: 0.4114, Validation accuracy: 0.9116
#
# Epoch 108:
# Training loss: 0.0153, Training accuracy: 0.9959
# Validation loss: 0.4159, Validation accuracy: 0.9032
#
# Epoch 109:
# Training loss: 0.0173, Training accuracy: 0.9960
# Validation loss: 0.4207, Validation accuracy: 0.9028
#
# Current learning rate has decayed to 0.000100
# Epoch 110:
# Training loss: 0.0129, Training accuracy: 0.9966
# Validation loss: 0.4281, Validation accuracy: 0.9016
#
# Epoch 111:
# Training loss: 0.0133, Training accuracy: 0.9968
# Validation loss: 0.4139, Validation accuracy: 0.9076
#
# Epoch 112:
# Training loss: 0.0121, Training accuracy: 0.9972
# Validation loss: 0.3980, Validation accuracy: 0.9104
#
# Epoch 113:
# Training loss: 0.0130, Training accuracy: 0.9968
# Validation loss: 0.3989, Validation accuracy: 0.9108
#
# Epoch 114:
# Training loss: 0.0132, Training accuracy: 0.9964
# Validation loss: 0.4107, Validation accuracy: 0.9012
#
# Epoch 115:
# Training loss: 0.0122, Training accuracy: 0.9965
# Validation loss: 0.4283, Validation accuracy: 0.9016
#
# Epoch 116:
# Training loss: 0.0137, Training accuracy: 0.9965
# Validation loss: 0.4145, Validation accuracy: 0.9092
#
# Epoch 117:
# Training loss: 0.0119, Training accuracy: 0.9970
# Validation loss: 0.3805, Validation accuracy: 0.9080
#
# Epoch 118:
# Training loss: 0.0125, Training accuracy: 0.9969
# Validation loss: 0.4100, Validation accuracy: 0.9072
#
# Epoch 119:
# Training loss: 0.0138, Training accuracy: 0.9974
# Validation loss: 0.4030, Validation accuracy: 0.9084
#
# Epoch 120:
# Training loss: 0.0140, Training accuracy: 0.9967
# Validation loss: 0.4040, Validation accuracy: 0.8996
#
# Epoch 121:
# Training loss: 0.0125, Training accuracy: 0.9965
# Validation loss: 0.4012, Validation accuracy: 0.9080
#
# Epoch 122:
# Training loss: 0.0114, Training accuracy: 0.9971
# Validation loss: 0.3959, Validation accuracy: 0.9072
#
# Epoch 123:
# Training loss: 0.0128, Training accuracy: 0.9968
# Validation loss: 0.4006, Validation accuracy: 0.9028
#
# Epoch 124:
# Training loss: 0.0117, Training accuracy: 0.9967
# Validation loss: 0.4170, Validation accuracy: 0.9100
#
# Epoch 125:
# Training loss: 0.0117, Training accuracy: 0.9970
# Validation loss: 0.4055, Validation accuracy: 0.9044
#
# Epoch 126:
# Training loss: 0.0118, Training accuracy: 0.9973
# Validation loss: 0.4005, Validation accuracy: 0.9072
#
# Epoch 127:
# Training loss: 0.0110, Training accuracy: 0.9973
# Validation loss: 0.4097, Validation accuracy: 0.9096
#
# Epoch 128:
# Training loss: 0.0108, Training accuracy: 0.9973
# Validation loss: 0.4307, Validation accuracy: 0.9040
#
# Epoch 129:
# Training loss: 0.0120, Training accuracy: 0.9969
# Validation loss: 0.4192, Validation accuracy: 0.9048
#
# Epoch 130:
# Training loss: 0.0111, Training accuracy: 0.9972
# Validation loss: 0.3790, Validation accuracy: 0.9028
#
# Epoch 131:
# Training loss: 0.0125, Training accuracy: 0.9973
# Validation loss: 0.4186, Validation accuracy: 0.9028
#
# Epoch 132:
# Training loss: 0.0111, Training accuracy: 0.9971
# Validation loss: 0.4383, Validation accuracy: 0.9064
#
# Epoch 133:
# Training loss: 0.0119, Training accuracy: 0.9968
# Validation loss: 0.4260, Validation accuracy: 0.9036
#
# Epoch 134:
# Training loss: 0.0111, Training accuracy: 0.9973
# Validation loss: 0.3842, Validation accuracy: 0.9076
#
# Epoch 135:
# Training loss: 0.0115, Training accuracy: 0.9972
# Validation loss: 0.3804, Validation accuracy: 0.9096
#
# Epoch 136:
# Training loss: 0.0119, Training accuracy: 0.9971
# Validation loss: 0.4169, Validation accuracy: 0.9100
#
# Epoch 137:
# Training loss: 0.0107, Training accuracy: 0.9976
# Validation loss: 0.4205, Validation accuracy: 0.9032
#
# Epoch 138:
# Training loss: 0.0112, Training accuracy: 0.9970
# Validation loss: 0.4169, Validation accuracy: 0.9036
#
# Epoch 139:
# Training loss: 0.0117, Training accuracy: 0.9971
# Validation loss: 0.4456, Validation accuracy: 0.9028
#
# Epoch 140:
# Training loss: 0.0111, Training accuracy: 0.9972
# Validation loss: 0.4026, Validation accuracy: 0.9064
#
# Epoch 141:
# Training loss: 0.0113, Training accuracy: 0.9973
# Validation loss: 0.4221, Validation accuracy: 0.9076
#
# Epoch 142:
# Training loss: 0.0115, Training accuracy: 0.9970
# Validation loss: 0.4244, Validation accuracy: 0.9076
#
# Epoch 143:
# Training loss: 0.0117, Training accuracy: 0.9971
# Validation loss: 0.3839, Validation accuracy: 0.9068
#
# Epoch 144:
# Training loss: 0.0119, Training accuracy: 0.9970
# Validation loss: 0.4094, Validation accuracy: 0.9112
#
# Epoch 145:
# Training loss: 0.0118, Training accuracy: 0.9971
# Validation loss: 0.4439, Validation accuracy: 0.9068
#
# Epoch 146:
# Training loss: 0.0109, Training accuracy: 0.9973
# Validation loss: 0.3863, Validation accuracy: 0.9052
#
# Epoch 147:
# Training loss: 0.0122, Training accuracy: 0.9975
# Validation loss: 0.4129, Validation accuracy: 0.9060
#
# Epoch 148:
# Training loss: 0.0121, Training accuracy: 0.9975
# Validation loss: 0.3975, Validation accuracy: 0.9080
#
# Epoch 149:
# Training loss: 0.0113, Training accuracy: 0.9972
# Validation loss: 0.4244, Validation accuracy: 0.9004
#
# ==================================================
# ==> Optimization finished! Best validation accuracy: 0.9144

# %%
resnet50 = ResNet50()
checkpoint = torch.load("./saved_model/resnet50_final.pth")
resnet50.load_state_dict(checkpoint['state_dict'])

test_model(resnet50)
# Out:
# Total examples is 10000, correct examples is 9079; Test accuracy: 0.9079
